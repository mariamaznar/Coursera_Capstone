# %% [markdown]
# ## Capstone Project - The Battle of Neighborhoods

# %% [markdown]
# ### WEEK 1

# %% [markdown]
# ## 1. Business Problem

# %% [markdown]
# Aim: analyse restaurants' market porfolio in Segovia to find a suitable location.
# Context: in this little town near Madrid there is no a huge variety of restaurants. A new chinese restaurant is planning to open. They know Segovian people really like this type of food, but it is not one of their first choices when thinking of a place to go for dinner/meal. Segovia is a very traditional town and they are used to eat their typical Spanish food. In this sense, this new chinese restaurant wants to capture the essence of Segovian's behaviour so they can attract their customers from this key point.
#
# - *What is the essence of Segovian's behaviour?*
#     Although Segovia is a very small town, their citizens always meet in the historic center of the city. The point of reference for meetings is the iconic Roman aqueduct, and nearby we can perceive a medieval environment with medieval walls, Romanesque churches, a former royal palace and a Gothic cathedral.
#
# - *What is the objective?*
#     This new Chinese restaurant is thinking about what location would be the best to capture the essence of Segovian's behaviour. They are considering placing outside the walls but near the hictoric center, but they are not sure if this is going to be the perfect place.
#
# Therefore, we are going to perform data analysis with python and foursquare data to obtain objective data about the restaurant's market porfolio and combined with previous qualitative data we have already gathered about Segovians, find the perfect location for this new restaurant to succeed.

# %% [markdown]
# ## 2. Data

# %% [markdown]
# -Data will include two neighbourhoods: inside city walls (historic center) or outside city walls (urban area).
# - We are going to analyse the venues in this two neighbourhoods:
#     - Frequency of restaurants to see where are placed most of the restaurants.
#                 If there are many restaurants concentrated in one neighbourhood this might be the right neighbourhood.
#                 What are the types of restaurants in the most populated area?
#                 Do this restaurantes match with the essence of Segovian's behaviour?
#     - Location of current chinese restaurants to analyse the competition.
#                 Is there an area where most chinese (or Asian) restaurants are concentrated?
#                 Can we find chinese restaurants in the most populated area?
#                 Do this current chinese restaurants match with the essence of Segovian's behaviour?
#     - Trigger venues (this are venues such as bars or pubs which can be determinant to choose where to go to have dinner/meal, i.e. if there are other venues nearby people might choose that place as it is close to those venues)
#                 Is there a specific leisure place within any of the neighbourhoods?
#                 Which venues can match with the essence of Segovian's behaviour?
#                 In which neighbourhood are placed the matching venues?
#
# - This quantitative data is going to be later interpreted in the context of the qualitative data we have available about habits and behaviour of Segovians.

# %% [markdown]
# ### WEEK 2

# %% [markdown]
# ## 3. Methodology

# %% [markdown]
# ### DATA PREPARATION

# %%
#Import all libraries needed to treat the data. We are considering only 2 neighbourhoods in Segovia: "CENTRO" and "LA GRANJA"
import pandas as pd
import numpy as np
import requests
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

# !conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

# !conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

print('Libraries imported.')
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/anaconda3
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     openssl-1.1.1g             |       haf1e3a3_1         1.9 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         1.9 MB
#
# The following packages will be DOWNGRADED:
#
#   openssl                                 1.1.1g-h0b31af3_1 --> 1.1.1g-haf1e3a3_1
#
#
#
# Downloading and Extracting Packages
# openssl-1.1.1g       | 1.9 MB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
# Libraries imported.

# %% [markdown]
# ###### Define Foursquare Credentials and Version

# %%
CLIENT_ID = 'XKA5QVXRYDRKMZQC5XLUZSUXZHCMTATNHPOLHLXODYTKNPVQ' # your Foursquare ID
CLIENT_SECRET = 'COQS5XDUCUSSZLN1ZDZ1C0ZMNHKUGT1OTQ4JJQ22ZBJ1ZDID' # your Foursquare Secret
VERSION = '20200811' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: XKA5QVXRYDRKMZQC5XLUZSUXZHCMTATNHPOLHLXODYTKNPVQ
# CLIENT_SECRET:COQS5XDUCUSSZLN1ZDZ1C0ZMNHKUGT1OTQ4JJQ22ZBJ1ZDID

# %% [markdown]
# #### SEGOVIA CENTRO NEIGHBOURHOOD

# %% [markdown]
# #### In the next step will gather all the venues placed in Segovia Centro neighbourhood. Our main focus are bars, restaurants and trigger venues.

# %%
#Obtain the geographical coordinades of Segovia Centro
address = 'Segovia, Spain'

geolocator = Nominatim(user_agent="toronto_explorer")
location = geolocator.geocode(address)
latitude_centro = location.latitude
longitude_centro = location.longitude
print('The geograpical coordinate of Segovia are {}, {}.'.format(latitude_centro, longitude_centro))
# Out:
# The geograpical coordinate of Segovia are 40.9502159, -4.1241494.

# %%
#GET request URL
LIMIT_centro = 100
radius_centro = 500
 
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(CLIENT_ID,CLIENT_SECRET, VERSION, latitude_centro, longitude_centro, radius_centro, LIMIT_centro)
results = requests.get(url).json()

# %%
results
# Out:
# {'meta': {'code': 200, 'requestId': '5f36b2ad6dd9a7231df4b0d0'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': 'Open now', 'key': 'openNow'}]},
#   'headerLocation': 'Segovia',
#   'headerFullLocation': 'Segovia',
#   'headerLocationGranularity': 'city',
#   'totalResults': 54,
#   'suggestedBounds': {'ne': {'lat': 40.954715904500006,
#     'lng': -4.118202457957227},
#    'sw': {'lat': 40.9457158955, 'lng': -4.130096342042774}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bdc7e7a3904a5938e704e9e',
#        'name': 'Catedral de Segovia',
#        'location': {'address': 'Pl. Mayor',
#         'crossStreet': 'C. Marqués de Arco',
#         'lat': 40.95012928546704,
#         'lng': -4.125484228134155,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.95012928546704,
#           'lng': -4.125484228134155}],
#         'distance': 112,
#         'postalCode': '40003',
#         'cc': 'ES',
#         'city': 'Segovia',
#         'state': 'Castilla y León',
#         'country': 'España',
#         'formattedAddress': ['Pl. Mayor (C. Marqués de Arco)',
#          '40003 Segovia Castilla y León',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d132941735',
#          'name': 'Church',
#          'pluralName': 'Churches',
#          'shortName': 'Church',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/religious_church_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bdc7e7a3904a5938e704e9e-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bd2e4a9b221c9b6796ad8d0',
#        'name': 'Restaurante José María',
#        'location': {'address': 'Calle del Cronista Lecea, 11, Bajo (Junto a Paza Mayor)',
#         'crossStreet': 'C. Cantabria',
#         'lat': 40.950508848,
#         'lng': -4.122547928,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.950508848,
#           'lng': -4.122547928}],
#         'distance': 138,
#         'postalCode': '40001',
#         'cc': 'ES',
#         'city': 'Segovia',
#         'state': 'Castilla y León',
#         'country': 'España',
#         'formattedAddress': ['Calle del Cronista Lecea, 11, Bajo (Junto a Paza Mayor) (C. Cantabria)',
#          '40001 Segovia Castilla y León',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d150941735',
#          'name': 'Spanish Restaurant',
#          'pluralName': 'Spanish Restaurants',
#          'shortName': 'Spanish',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/spanish_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '51689095'}},
#       'referralId': 'e-0-4bd2e4a9b221c9b6796ad8d0-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bdc7dba2a3a0f472216b3b6',
#        'name': 'Plaza Mayor',
#        'location': {'address': 'Pz. Mayor',
#         'lat': 40.950176152435894,
#         'lng': -4.124077747812835,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.950176152435894,
#           'lng': -4.124077747812835}],
#         'distance': 7,
#         'postalCode': '40001',
#         'cc': 'ES',
#         'city': 'Segovia',
#         'state': 'Castilla y León',
#         'country': 'España',
#         'formattedAddress': ['Pz. Mayor',
#          '40001 Segovia Castilla y León',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d164941735',
#          'name': 'Plaza',
#          'pluralName': 'Plazas',
#          'shortName': 'Plaza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/plaza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bdc7dba2a3a0f472216b3b6-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bdc5a202a3a0f47c76eb2b6',
#        'name': 'Limón y Menta',
#        'location': {'address': 'C/Isabel la Católica 2',
#         'lat': 40.949924,
#         'lng': -4.124142,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.949924,
#           'lng': -4.124142}],
#         'distance': 32,
#         'postalCode': '40001',
#         'cc': 'ES',
#         'city': 'Segovia',
#         'state': 'Castilla y León',
#         'country': 'España',
#         'formattedAddress': ['C/Isabel la Católica 2',
#          '40001 Segovia Castilla y León',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1d0941735',
#          'name': 'Dessert Shop',
#          'pluralName': 'Dessert Shops',
#          'shortName': 'Desserts',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dessert_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bdc5a202a3a0f47c76eb2b6-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5049c894e4b0e1f2666f2f65',
#        'name': 'Olivia Lab & Soap Room',
#        'location': {'address': 'Plaza Doctor Laguna, 2',
#         'lat': 40.95044936420683,
#         'lng': -4.12136435508728,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.95044936420683,
#           'lng': -4.12136435508728}],
#         'distance': 235,
#         'postalCode': '40001',
#         'cc': 'ES',
#         'city': 'Segovia',
#         'state': 'Castilla y León',
#         'country': 'España',
#         'formattedAddress': ['Plaza Doctor Laguna, 2',
#          '40001 Segovia Castilla y León',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1ff941735',
#          'name': 'Miscellaneous Shop',
#          'pluralName': 'Miscellaneous Shops',
#          'shortName': 'Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5049c894e4b0e1f2666f2f65-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '53d3087b498e67ffa95e92a5',
#        'name': 'Hotel Eurostars Convento Capuchinos 5*',
#        'location': {'address': 'Plazuela de Capuchinos, 2',
#         'lat': 40.95206787274508,
#         'lng': -4.123042000549077,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.95206787274508,
#           'lng': -4.123042000549077}],
#         'distance': 226,
#         'postalCode': '40001',
#         'cc': 'ES',
#         'city': 'Segovia',
#         'state': 'Castilla y León',
#         'country': 'España',
#         'formattedAddress': ['Plazuela de Capuchinos, 2',
#          '40001 Segovia Castilla y León',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-53d3087b498e67ffa95e92a5-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e6240bf62e13e3bce8c8bca',
#        'name': 'El Redebal',
#        'location': {'address': 'Pz. Alhondiga 6',
#         'lat': 40.94825634304775,
#         'lng': -4.12184346409547,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.94825634304775,
#           'lng': -4.12184346409547}],
#         'distance': 291,
#         'postalCode': '40001',
#         'cc': 'ES',
#         'city': 'Segovia',
#         'state': 'Castilla y León',
#         'country': 'España',
#         'formattedAddress': ['Pz. Alhondiga 6',
#          '40001 Segovia Castilla y León',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d150941735',
#          'name': 'Spanish Restaurant',
#          'pluralName': 'Spanish Restaurants',
#          'shortName': 'Spanish',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/spanish_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e6240bf62e13e3bce8c8bca-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bc32457920eb71360ff1c2c',
#        'name': 'El Sitio',
#        'location': {'address': 'Calle de la Infanta Isabel, 9, Bajo',
#         'crossStreet': 'Travesia del Patín',
#         'lat': 40.949791705240536,
#         'lng': -4.123002781002015,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.949791705240536,
#           'lng': -4.123002781002015}],
#         'distance': 107,
#         'postalCode': '40001',
#         'cc': 'ES',
#         'city': 'Segovia',
#         'state': 'Castilla y León',
#         'country': 'España',
#         'formattedAddress': ['Calle de la Infanta Isabel, 9, Bajo (Travesia del Patín)',
#          '40001 Segovia Castilla y León',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d116941735',
#          'name': 'Bar',
#          'pluralName': 'Bars',
#          'shortName': 'Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bc32457920eb71360ff1c2c-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e35b2651838f85189a9a065',
#        'name': 'Paseo Del Salón De Isabel II',
#        'location': {'lat': 40.94864077348275,
#         'lng': -4.123334975859352,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.94864077348275,
#           'lng': -4.123334975859352}],
#         'distance': 188,
#         'cc': 'ES',
#         'country': 'España',
#         'formattedAddress': ['España']},
#        'categories': [{'id': '4bf58dd8d48988d163941735',
#          'name': 'Park',
#          'pluralName': 'Parks',
#          'shortName': 'Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e35b2651838f85189a9a065-8'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b6457d9f964a52004ac2ae3',
#        'name': 'Cueva de San Esteban',
#        'location': {'crossStreet': 'Valdelaguila, 15',
#         'lat': 40.951251303868034,
#         'lng': -4.124471712192861,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.951251303868034,
#           'lng': -4.124471712192861}],
#         'distance': 118,
#         'cc': 'ES',
#         'city': 'Segovia',
#         'state': 'Castilla y León',
#         'country': 'España',
#         'formattedAddress': ['Segovia Castilla y León', 'España']},
#        'categories': [{'id': '4bf58dd8d48988d150941735',
#          'name': 'Spanish Restaurant',
#          'pluralName': 'Spanish Restaurants',
#          'shortName': 'Spanish',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/spanish_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b6457d9f964a52004ac2ae3-9'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '51e3c943498e9a066d28d64f',
#        'name': 'Granier',
#        'location': {'address': 'Calle Juan Bravo 3',
#         'crossStreet': 'Plaza Corpus',
#         'lat': 40.949307210944326,
#         'lng': -4.123373173797959,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.949307210944326,
#           'lng': -4.123373173797959}],
#         'distance': 120,
#         'postalCode': '40001',
#         'cc': 'ES',
#         'city': 'Segovia',
#         'state': 'Castilla y León',
#         'country': 'España',
#         'formattedAddress': ['Calle Juan Bravo 3 (Plaza Corpus)',
#          '40001 Segovia Castilla y León',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-51e3c943498e9a066d28d64f-10'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '550b4363498eb82584f9fa8b',
#        'name': 'Restaurante Villena',
#        'location': {'address': 'Pl. Capuchinos, 2',
#         'lat': 40.95217,
#         'lng': -4.122966,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.95217,
#           'lng': -4.122966}],
#         'distance': 239,
#         'postalCode': '40001',
#         'cc': 'ES',
#         'city': 'Segovia',
#         'state': 'Castilla y León',
#         'country': 'España',
#         'formattedAddress': ['Pl. Capuchinos, 2',
#          '40001 Segovia Castilla y León',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d150941735',
#          'name': 'Spanish Restaurant',
#          'pluralName': 'Spanish Restaurants',
#          'shortName': 'Spanish',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/spanish_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-550b4363498eb82584f9fa8b-11'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c9deca97c096dcbce93cfd1',
#        'name': 'El Fogón Sefardí',
#        'location': {'address': 'C. Judería Vieja, 17',
#         'lat': 40.94962906862783,
#         'lng': -4.124279938874181,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.94962906862783,
#           'lng': -4.124279938874181}],
#         'distance': 66,
#         'postalCode': '40001',
#         'cc': 'ES',
#         'city': 'Segovia',
#         'state': 'Castilla y León',
#         'country': 'España',
#         'formattedAddress': ['C. Judería Vieja, 17',
#          '40001 Segovia Castilla y León',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1db931735',
#          'name': 'Tapas Restaurant',
#          'pluralName': 'Tapas Restaurants',
#          'shortName': 'Tapas',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/tapas_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c9deca97c096dcbce93cfd1-12'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bd37159b221c9b6c4cbd9d0',
#        'name': 'Santana',
#        'location': {'address': 'C. Infanta Isabel, 18',
#         'lat': 40.94964517199829,
#         'lng': -4.122629373257897,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.94964517199829,
#           'lng': -4.122629373257897}],
#         'distance': 142,
#         'postalCode': '40001',
#         'cc': 'ES',
#         'city': 'Segovia',
#         'state': 'Castilla y León',
#         'country': 'España',
#         'formattedAddress': ['C. Infanta Isabel, 18',
#          '40001 Segovia Castilla y León',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d116941735',
#          'name': 'Bar',
#          'pluralName': 'Bars',
#          'shortName': 'Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bd37159b221c9b6c4cbd9d0-13'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4db2949b5da3944066baaf0a',
#        'name': 'Plazas de San Martín y Medina del Campo',
#        'location': {'lat': 40.94874384470879,
#         'lng': -4.1217521726077635,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.94874384470879,
#           'lng': -4.1217521726077635}],
#         'distance': 259,
#         'cc': 'ES',
#         'city': 'Segovia',
#         'state': 'Castilla y León',
#         'country': 'España',
#         'formattedAddress': ['Segovia Castilla y León', 'España']},
#        'categories': [{'id': '4bf58dd8d48988d164941735',
#          'name': 'Plaza',
#          'pluralName': 'Plazas',
#          'shortName': 'Plaza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/plaza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4db2949b5da3944066baaf0a-14'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ce6d621fe90a35d178d380e',
#        'name': 'El Figón De Los Comuneros',
#        'location': {'address': 'Travesía del Patín 4',
#         'lat': 40.94985505073359,
#         'lng': -4.123007127271221,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.94985505073359,
#           'lng': -4.123007127271221}],
#         'distance': 104,
#         'postalCode': '40001',
#         'cc': 'ES',
#         'city': 'Segovia',
#         'state': 'Castilla y León',
#         'country': 'España',
#         'formattedAddress': ['Travesía del Patín 4',
#          '40001 Segovia Castilla y León',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d116941735',
#          'name': 'Bar',
#          'pluralName': 'Bars',
#          'shortName': 'Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ce6d621fe90a35d178d380e-15'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '51584ccce4b0226ab8b92205',
#        'name': 'Llaollao',
#        'location': {'address': 'Pz. Corpus 2',
#         'lat': 40.94942,
#         'lng': -4.123543,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.94942,
#           'lng': -4.123543}],
#         'distance': 102,
#         'postalCode': '40001',
#         'cc': 'ES',
#         'city': 'Segovia',
#         'state': 'Castilla y León',
#         'country': 'España',
#         'formattedAddress': ['Pz. Corpus 2',
#          '40001 Segovia Castilla y León',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1c9941735',
#          'name': 'Ice Cream Shop',
#          'pluralName': 'Ice Cream Shops',
#          'shortName': 'Ice Cream',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/icecream_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-51584ccce4b0226ab8b92205-16'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e4826ab887781a619c1bcbb',
#        'name': 'Barrio de la Judería',
#        'location': {'lat': 40.94868386252083,
#         'lng': -4.122215927642986,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.94868386252083,
#           'lng': -4.122215927642986}],
#         'distance': 235,
#         'postalCode': '40100',
#         'cc': 'ES',
#         'city': 'Segovia',
#         'state': 'Castilla y León',
#         'country': 'España',
#         'formattedAddress': ['40100 Segovia Castilla y León', 'España']},
#        'categories': [{'id': '4deefb944765f83613cdba6e',
#          'name': 'Historic Site',
#          'pluralName': 'Historic Sites',
#          'shortName': 'Historic Site',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/historicsite_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e4826ab887781a619c1bcbb-17'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bd2f112a8b3a5931cb6685f',
#        'name': 'Narizotas',
#        'location': {'address': 'Pl. Medina del Campo, 2',
#         'lat': 40.948736007915095,
#         'lng': -4.121634638103716,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.948736007915095,
#           'lng': -4.121634638103716}],
#         'distance': 268,
#         'postalCode': '40001',
#         'cc': 'ES',
#         'city': 'Segovia',
#         'state': 'Castilla y León',
#         'country': 'España',
#         'formattedAddress': ['Pl. Medina del Campo, 2',
#          '40001 Segovia Castilla y León',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d150941735',
#          'name': 'Spanish Restaurant',
#          'pluralName': 'Spanish Restaurants',
#          'shortName': 'Spanish',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/spanish_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bd2f112a8b3a5931cb6685f-18'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5155953de4b0656945b116a5',
#        'name': 'El Hidalgo',
#        'location': {'lat': 40.94932525580901,
#         'lng': -4.122078151866744,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.94932525580901,
#           'lng': -4.122078151866744}],
#         'distance': 200,
#         'cc': 'ES',
#         'country': 'España',
#         'formattedAddress': ['España']},
#        'categories': [{'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'shortName': 'Restaurant',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5155953de4b0656945b116a5-19'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bb0ce34f964a520a25e3ce3',
#        'name': 'La Judería',
#        'location': {'address': 'C/Juderia vieja 5',
#         'lat': 40.94953154779561,
#         'lng': -4.124927697689212,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.94953154779561,
#           'lng': -4.124927697689212}],
#         'distance': 100,
#         'postalCode': '40001',
#         'cc': 'ES',
#         'city': 'Segovia',
#         'state': 'Castilla y León',
#         'country': 'España',
#         'formattedAddress': ['C/Juderia vieja 5',
#          '40001 Segovia Castilla y León',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d10f941735',
#          'name': 'Indian Restaurant',
#          'pluralName': 'Indian Restaurants',
#          'shortName': 'Indian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bb0ce34f964a520a25e3ce3-20'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d79372671a68cfad4f81286',
#        'name': 'La Almuzara',
#        'location': {'address': 'C/Marques del Arco 3',
#         'lat': 40.95091935043053,
#         'lng': -4.126267433166504,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.95091935043053,
#           'lng': -4.126267433166504}],
#         'distance': 194,
#         'postalCode': '40003',
#         'cc': 'ES',
#         'city': 'Segovia',
#         'state': 'Castilla y León',
#         'country': 'España',
#         'formattedAddress': ['C/Marques del Arco 3',
#          '40003 Segovia Castilla y León',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1d3941735',
#          'name': 'Vegetarian / Vegan Restaurant',
#          'pluralName': 'Vegetarian / Vegan Restaurants',
#          'shortName': 'Vegetarian / Vegan',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d79372671a68cfad4f81286-21'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f48ebaae4b0db1b358305af',
#        'name': 'Taberna Rubi',
#        'location': {'address': 'Calle Escuderos, 4',
#         'crossStreet': 'Plaza Mayor',
#         'lat': 40.950393,
#         'lng': -4.124475,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.950393,
#           'lng': -4.124475}],
#         'distance': 33,
#         'cc': 'ES',
#         'city': 'Segovia',
#         'state': 'Castilla y León',
#         'country': 'España',
#         'formattedAddress': ['Calle Escuderos, 4 (Plaza Mayor)',
#          'Segovia Castilla y León',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d116941735',
#          'name': 'Bar',
#          'pluralName': 'Bars',
#          'shortName': 'Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4f48ebaae4b0db1b358305af-22'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bdc81b4c79cc92837de86e9',
#        'name': 'La Tasquina',
#        'location': {'address': 'Valdeláguila, 3',
#         'lat': 40.95102003452052,
#         'lng': -4.123438638950267,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.95102003452052,
#           'lng': -4.123438638950267}],
#         'distance': 107,
#         'cc': 'ES',
#         'city': 'Segovia',
#         'state': 'Castilla y León',
#         'country': 'España',
#         'formattedAddress': ['Valdeláguila, 3',
#          'Segovia Castilla y León',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d123941735',
#          'name': 'Wine Bar',
#          'pluralName': 'Wine Bars',
#          'shortName': 'Wine Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/winery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bdc81b4c79cc92837de86e9-23'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4dd84aef2271c5d36d5185af',
#        'name': 'Beat Club',
#        'location': {'lat': 40.94765652270144,
#         'lng': -4.122019123937236,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.94765652270144,
#           'lng': -4.122019123937236}],
#         'distance': 336,
#         'cc': 'ES',
#         'city': 'Segovia',
#         'state': 'Castilla y León',
#         'country': 'España',
#         'formattedAddress': ['Segovia Castilla y León', 'España']},
#        'categories': [{'id': '4bf58dd8d48988d1e9931735',
#          'name': 'Rock Club',
#          'pluralName': 'Rock Clubs',
#          'shortName': 'Rock Club',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_rockclub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4dd84aef2271c5d36d5185af-24'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4db9ac6f6e818f67a9c4416a',
#        'name': 'Teatro Juan Bravo',
#        'location': {'address': 'Plaza Mayor',
#         'lat': 40.950331264684884,
#         'lng': -4.123959152418482,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.950331264684884,
#           'lng': -4.123959152418482}],
#         'distance': 20,
#         'cc': 'ES',
#         'city': 'Segovia',
#         'state': 'Castilla y León',
#         'country': 'España',
#         'formattedAddress': ['Plaza Mayor',
#          'Segovia Castilla y León',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d137941735',
#          'name': 'Theater',
#          'pluralName': 'Theaters',
#          'shortName': 'Theater',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/performingarts_theater_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4db9ac6f6e818f67a9c4416a-25'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '55c65f2b498e4521e89f2228',
#        'name': 'Café Jeyma',
#        'location': {'address': 'Plaza mayor',
#         'lat': 40.95047051590093,
#         'lng': -4.123619737486133,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.95047051590093,
#           'lng': -4.123619737486133}],
#         'distance': 52,
#         'cc': 'ES',
#         'country': 'España',
#         'formattedAddress': ['Plaza mayor', 'España']},
#        'categories': [{'id': '4bf58dd8d48988d150941735',
#          'name': 'Spanish Restaurant',
#          'pluralName': 'Spanish Restaurants',
#          'shortName': 'Spanish',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/spanish_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-55c65f2b498e4521e89f2228-26'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d987b3861a3a1cdd547ce42',
#        'name': 'Restaurante California',
#        'location': {'address': 'Plaza Doctor Gila, 5',
#         'lat': 40.94673352080643,
#         'lng': -4.121496552148366,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.94673352080643,
#           'lng': -4.121496552148366}],
#         'distance': 447,
#         'postalCode': '40002',
#         'cc': 'ES',
#         'city': 'Segovia',
#         'state': 'Castilla y León',
#         'country': 'España',
#         'formattedAddress': ['Plaza Doctor Gila, 5',
#          '40002 Segovia Castilla y León',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'shortName': 'Restaurant',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d987b3861a3a1cdd547ce42-27'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e6a0af252b1c1205f9e614b',
#        'name': 'Meson Don Jimeno',
#        'location': {'lat': 40.952048648025745,
#         'lng': -4.128870620050462,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.952048648025745,
#           'lng': -4.128870620050462}],
#         'distance': 446,
#         'postalCode': '40003',
#         'cc': 'ES',
#         'city': 'Segovia',
#         'state': 'Castilla y León',
#         'country': 'España',
#         'formattedAddress': ['40003 Segovia Castilla y León', 'España']},
#        'categories': [{'id': '4bf58dd8d48988d150941735',
#          'name': 'Spanish Restaurant',
#          'pluralName': 'Spanish Restaurants',
#          'shortName': 'Spanish',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/spanish_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e6a0af252b1c1205f9e614b-28'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4dc6668dfa76d685cdf923dd',
#        'name': 'Mirador de Canaleja',
#        'location': {'address': 'Calle de Cervantes, 2-4',
#         'lat': 40.94778547531399,
#         'lng': -4.120437183805555,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.94778547531399,
#           'lng': -4.120437183805555}],
#         'distance': 413,
#         'postalCode': '40001',
#         'cc': 'ES',
#         'city': 'Segovia',
#         'state': 'Castilla y León',
#         'country': 'España',
#         'formattedAddress': ['Calle de Cervantes, 2-4',
#          '40001 Segovia Castilla y León',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d165941735',
#          'name': 'Scenic Lookout',
#          'pluralName': 'Scenic Lookouts',
#          'shortName': 'Scenic Lookout',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/sceniclookout_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4dc6668dfa76d685cdf923dd-29'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b76a5f6f964a52053562ee3',
#        'name': 'Casa Duque',
#        'location': {'address': 'C. Cervantes, 12',
#         'lat': 40.94783852938986,
#         'lng': -4.11983755020578,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.94783852938986,
#           'lng': -4.11983755020578}],
#         'distance': 448,
#         'postalCode': '40001',
#         'cc': 'ES',
#         'city': 'Segovia',
#         'state': 'Castilla y León',
#         'country': 'España',
#         'formattedAddress': ['C. Cervantes, 12',
#          '40001 Segovia Castilla y León',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d150941735',
#          'name': 'Spanish Restaurant',
#          'pluralName': 'Spanish Restaurants',
#          'shortName': 'Spanish',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/spanish_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b76a5f6f964a52053562ee3-30'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '519683e4498e4d7d9679eca5',
#        'name': 'Julián Duque',
#        'location': {'lat': 40.95040164996555,
#         'lng': -4.12383973558209,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.95040164996555,
#           'lng': -4.12383973558209}],
#         'distance': 33,
#         'cc': 'ES',
#         'country': 'España',
#         'formattedAddress': ['España']},
#        'categories': [{'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'shortName': 'Restaurant',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-519683e4498e4d7d9679eca5-31'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b76117bf964a5207f3a2ee3',
#        'name': 'Hotel Los Linajes',
#        'location': {'lat': 40.952589,
#         'lng': -4.125339,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.952589,
#           'lng': -4.125339}],
#         'distance': 282,
#         'cc': 'ES',
#         'country': 'España',
#         'formattedAddress': ['España']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b76117bf964a5207f3a2ee3-32'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bdc51c1c79cc928bcfa85e9',
#        'name': 'Meson El Cordero',
#        'location': {'address': 'Bajada del Cármen 4',
#         'lat': 40.94725203188481,
#         'lng': -4.119705834045987,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.94725203188481,
#           'lng': -4.119705834045987}],
#         'distance': 498,
#         'cc': 'ES',
#         'city': 'Segovia',
#         'state': 'Castilla y León',
#         'country': 'España',
#         'formattedAddress': ['Bajada del Cármen 4',
#          'Segovia Castilla y León',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d150941735',
#          'name': 'Spanish Restaurant',
#          'pluralName': 'Spanish Restaurants',
#          'shortName': 'Spanish',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/spanish_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bdc51c1c79cc928bcfa85e9-33'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e5cd4b218a8a75fa27419b2',
#        'name': 'Restaurante Lázaro',
#        'location': {'lat': 40.950027202494944,
#         'lng': -4.123404917167906,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.950027202494944,
#           'lng': -4.123404917167906}],
#         'distance': 66,
#         'cc': 'ES',
#         'country': 'España',
#         'formattedAddress': ['España']},
#        'categories': [{'id': '4bf58dd8d48988d150941735',
#          'name': 'Spanish Restaurant',
#          'pluralName': 'Spanish Restaurants',
#          'shortName': 'Spanish',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/spanish_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e5cd4b218a8a75fa27419b2-34'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c2fbb02452620a19c151e0f',
#        'name': 'Cafe Restaurante Infante',
#        'location': {'address': 'C. Isabel La Catolica, 1',
#         'lat': 40.95003451718396,
#         'lng': -4.123982974186628,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.95003451718396,
#           'lng': -4.123982974186628}],
#         'distance': 24,
#         'postalCode': '40001',
#         'cc': 'ES',
#         'city': 'Segovia',
#         'state': 'Castilla y León',
#         'country': 'España',
#         'formattedAddress': ['C. Isabel La Catolica, 1',
#          '40001 Segovia Castilla y León',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1db931735',
#          'name': 'Tapas Restaurant',
#          'pluralName': 'Tapas Restaurants',
#          'shortName': 'Tapas',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/tapas_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c2fbb02452620a19c151e0f-35'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bb5eb4e46d4a593fd70c5c0',
#        'name': 'El Bernardino',
#        'location': {'address': 'C. Cervantes, 3',
#         'lat': 40.947788133490654,
#         'lng': -4.1202328466786575,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.947788133490654,
#           'lng': -4.1202328466786575}],
#         'distance': 425,
#         'postalCode': '40001',
#         'cc': 'ES',
#         'city': 'Segovia',
#         'state': 'Castilla y León',
#         'country': 'España',
#         'formattedAddress': ['C. Cervantes, 3',
#          '40001 Segovia Castilla y León',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d150941735',
#          'name': 'Spanish Restaurant',
#          'pluralName': 'Spanish Restaurants',
#          'shortName': 'Spanish',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/spanish_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bb5eb4e46d4a593fd70c5c0-36'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d72a44e311f6ea8e6e4deea',
#        'name': 'Las Tres BBB',
#        'location': {'address': 'Pl. Mayor 13',
#         'lat': 40.9502663807451,
#         'lng': -4.124144883390609,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.9502663807451,
#           'lng': -4.124144883390609}],
#         'distance': 5,
#         'postalCode': '40001',
#         'cc': 'ES',
#         'city': 'Segovia',
#         'state': 'Castilla y León',
#         'country': 'España',
#         'formattedAddress': ['Pl. Mayor 13',
#          '40001 Segovia Castilla y León',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d150941735',
#          'name': 'Spanish Restaurant',
#          'pluralName': 'Spanish Restaurants',
#          'shortName': 'Spanish',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/spanish_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d72a44e311f6ea8e6e4deea-37'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b900145f964a520956f33e3',
#        'name': 'La Bodega del Barbero',
#        'location': {'address': 'Alhóndiga, 2',
#         'lat': 40.94840255719314,
#         'lng': -4.121622826468506,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.94840255719314,
#           'lng': -4.121622826468506}],
#         'distance': 293,
#         'cc': 'ES',
#         'city': 'Segovia',
#         'state': 'Castilla y León',
#         'country': 'España',
#         'formattedAddress': ['Alhóndiga, 2',
#          'Segovia Castilla y León',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1db931735',
#          'name': 'Tapas Restaurant',
#          'pluralName': 'Tapas Restaurants',
#          'shortName': 'Tapas',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/tapas_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b900145f964a520956f33e3-38'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4dfcdf6362846d918b95b3a7',
#        'name': 'Hotel Don Felipe',
#        'location': {'address': 'C/ daoiz n7',
#         'lat': 40.9516951056794,
#         'lng': -4.128463389755442,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.9516951056794,
#           'lng': -4.128463389755442}],
#         'distance': 398,
#         'cc': 'ES',
#         'city': 'Segovia',
#         'state': 'Castilla y León',
#         'country': 'España',
#         'formattedAddress': ['C/ daoiz n7',
#          'Segovia Castilla y León',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4dfcdf6362846d918b95b3a7-39'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ea42d3e29c2abc8df8177d2',
#        'name': 'Casa Museo De Antonio Machado',
#        'location': {'lat': 40.951575395055464,
#         'lng': -4.125842929801457,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.951575395055464,
#           'lng': -4.125842929801457}],
#         'distance': 207,
#         'cc': 'ES',
#         'country': 'España',
#         'formattedAddress': ['España']},
#        'categories': [{'id': '4deefb944765f83613cdba6e',
#          'name': 'Historic Site',
#          'pluralName': 'Historic Sites',
#          'shortName': 'Historic Site',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/historicsite_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ea42d3e29c2abc8df8177d2-40'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d239152cc84721ead7661f6',
#        'name': 'La Concepción',
#        'location': {'address': 'Plaza Mayor, 15, BAJO;LOCAL',
#         'lat': 40.950387564,
#         'lng': -4.124351036,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.950387564,
#           'lng': -4.124351036}],
#         'distance': 25,
#         'postalCode': '40001',
#         'cc': 'ES',
#         'city': 'Segovia',
#         'state': 'Castilla y León',
#         'country': 'España',
#         'formattedAddress': ['Plaza Mayor, 15, BAJO;LOCAL',
#          '40001 Segovia Castilla y León',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d150941735',
#          'name': 'Spanish Restaurant',
#          'pluralName': 'Spanish Restaurants',
#          'shortName': 'Spanish',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/spanish_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d239152cc84721ead7661f6-41'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f9fdde4e4b0492c19880053',
#        'name': 'Bar Socorro',
#        'location': {'lat': 40.95013345976627,
#         'lng': -4.127354420310348,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.95013345976627,
#           'lng': -4.127354420310348}],
#         'distance': 269,
#         'cc': 'ES',
#         'country': 'España',
#         'formattedAddress': ['España']},
#        'categories': [{'id': '4bf58dd8d48988d116941735',
#          'name': 'Bar',
#          'pluralName': 'Bars',
#          'shortName': 'Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4f9fdde4e4b0492c19880053-42'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cdef2e294c3b60cc7b468ea',
#        'name': 'El Ojo',
#        'location': {'lat': 40.948808,
#         'lng': -4.121398,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.948808,
#           'lng': -4.121398}],
#         'distance': 279,
#         'cc': 'ES',
#         'country': 'España',
#         'formattedAddress': ['España']},
#        'categories': [{'id': '4bf58dd8d48988d116941735',
#          'name': 'Bar',
#          'pluralName': 'Bars',
#          'shortName': 'Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cdef2e294c3b60cc7b468ea-43'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cce11e7aa25a35ddbd31e0f',
#        'name': "Canavan's",
#        'location': {'address': 'Pz. La rubia 2',
#         'lat': 40.95046462800822,
#         'lng': -4.12236985785248,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.95046462800822,
#           'lng': -4.12236985785248}],
#         'distance': 152,
#         'postalCode': '40001',
#         'cc': 'ES',
#         'city': 'Segovia',
#         'state': 'Castilla y León',
#         'country': 'España',
#         'formattedAddress': ['Pz. La rubia 2',
#          '40001 Segovia Castilla y León',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d117941735',
#          'name': 'Beer Garden',
#          'pluralName': 'Beer Gardens',
#          'shortName': 'Beer Garden',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/beergarden_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cce11e7aa25a35ddbd31e0f-44'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e4503f8e4cd394059f094cc',
#        'name': 'Monumento a Juan Bravo',
#        'location': {'address': 'Plaza de Medina del Campo',
#         'lat': 40.948591547457944,
#         'lng': -4.121617199189222,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.948591547457944,
#           'lng': -4.121617199189222}],
#         'distance': 279,
#         'postalCode': '40001',
#         'cc': 'ES',
#         'city': 'Segovia',
#         'state': 'Castilla y León',
#         'country': 'España',
#         'formattedAddress': ['Plaza de Medina del Campo',
#          '40001 Segovia Castilla y León',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d166941735',
#          'name': 'Sculpture Garden',
#          'pluralName': 'Sculpture Gardens',
#          'shortName': 'Sculpture',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/sculpture_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e4503f8e4cd394059f094cc-45'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c8cd502f87e224b241e3805',
#        'name': "Foster's Hollywood",
#        'location': {'address': 'C/Juan Bravo, 30',
#         'lat': 40.94848566459911,
#         'lng': -4.122177911727256,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.94848566459911,
#           'lng': -4.122177911727256}],
#         'distance': 254,
#         'postalCode': '40001',
#         'cc': 'ES',
#         'city': 'Segovia',
#         'state': 'Castilla y León',
#         'country': 'España',
#         'formattedAddress': ['C/Juan Bravo, 30',
#          '40001 Segovia Castilla y León',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d14e941735',
#          'name': 'American Restaurant',
#          'pluralName': 'American Restaurants',
#          'shortName': 'American',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c8cd502f87e224b241e3805-46'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4eeb853ae3000c69e1a69b6f',
#        'name': 'Museo de Segovia',
#        'location': {'address': 'Calle del Socorro, 11, 40003 Segovia',
#         'lat': 40.950416244612036,
#         'lng': -4.128395970559245,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.950416244612036,
#           'lng': -4.128395970559245}],
#         'distance': 357,
#         'postalCode': '40003',
#         'cc': 'ES',
#         'city': 'Segovia',
#         'state': 'Castilla y León',
#         'country': 'España',
#         'formattedAddress': ['Calle del Socorro, 11, 40003 Segovia',
#          '40003 Segovia Castilla y León',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d181941735',
#          'name': 'Museum',
#          'pluralName': 'Museums',
#          'shortName': 'Museum',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4eeb853ae3000c69e1a69b6f-47'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d13b36b2b1fa35d71d84ab1',
#        'name': 'Las Cuevas de Duque',
#        'location': {'address': 'C. de Sante Engracia',
#         'lat': 40.947764684273686,
#         'lng': -4.119530589510082,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.947764684273686,
#           'lng': -4.119530589510082}],
#         'distance': 474,
#         'cc': 'ES',
#         'city': 'Segovia',
#         'state': 'Castilla y León',
#         'country': 'España',
#         'formattedAddress': ['C. de Sante Engracia',
#          'Segovia Castilla y León',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d116941735',
#          'name': 'Bar',
#          'pluralName': 'Bars',
#          'shortName': 'Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d13b36b2b1fa35d71d84ab1-48'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '503cde37e0e262fd8820e0be',
#        'name': 'Ö!MYGOOD Segovia',
#        'location': {'address': 'Cervantes, 19',
#         'lat': 40.94781300444335,
#         'lng': -4.119128677712605,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.94781300444335,
#           'lng': -4.119128677712605}],
#         'distance': 499,
#         'postalCode': '40001',
#         'cc': 'ES',
#         'city': 'Segovia',
#         'state': 'Castilla y León',
#         'country': 'España',
#         'formattedAddress': ['Cervantes, 19',
#          '40001 Segovia Castilla y León',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1c9941735',
#          'name': 'Ice Cream Shop',
#          'pluralName': 'Ice Cream Shops',
#          'shortName': 'Ice Cream',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/icecream_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-503cde37e0e262fd8820e0be-49'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4de149c6fa76425c542f0f60',
#        'name': 'La Floresta',
#        'location': {'lat': 40.94997717555854,
#         'lng': -4.118298590024267,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.94997717555854,
#           'lng': -4.118298590024267}],
#         'distance': 492,
#         'cc': 'ES',
#         'city': 'Segovia',
#         'state': 'Castilla y León',
#         'country': 'España',
#         'formattedAddress': ['Segovia Castilla y León', 'España']},
#        'categories': [{'id': '4bf58dd8d48988d150941735',
#          'name': 'Spanish Restaurant',
#          'pluralName': 'Spanish Restaurants',
#          'shortName': 'Spanish',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/spanish_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4de149c6fa76425c542f0f60-50'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bcf4b2e0ffdce72305cb2c0',
#        'name': 'Hotel Palacio San Facundo',
#        'location': {'address': 'Plaza de San Facundo, 4, BAJO',
#         'lat': 40.950216442,
#         'lng': -4.120389531,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.950216442,
#           'lng': -4.120389531}],
#         'distance': 316,
#         'postalCode': '40001',
#         'cc': 'ES',
#         'city': 'Segovia',
#         'state': 'Castilla y León',
#         'country': 'España',
#         'formattedAddress': ['Plaza de San Facundo, 4, BAJO',
#          '40001 Segovia Castilla y León',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bcf4b2e0ffdce72305cb2c0-51'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '56efea97498e06e63abc7fe6',
#        'name': 'VIPS Smart Segovia',
#        'location': {'address': 'C. Cervantes, 16',
#         'lat': 40.94778724500055,
#         'lng': -4.119683170338678,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.94778724500055,
#           'lng': -4.119683170338678}],
#         'distance': 462,
#         'postalCode': '40001',
#         'cc': 'ES',
#         'city': 'Segovia',
#         'state': 'Castilla y León',
#         'country': 'España',
#         'formattedAddress': ['C. Cervantes, 16',
#          '40001 Segovia Castilla y León',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'shortName': 'Restaurant',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-56efea97498e06e63abc7fe6-52'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '54df5a65498e7eda5ddacacb',
#        'name': 'Taberna de Volapie',
#        'location': {'lat': 40.94776348419871,
#         'lng': -4.119223590447673,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.94776348419871,
#           'lng': -4.119223590447673}],
#         'distance': 496,
#         'cc': 'ES',
#         'country': 'España',
#         'formattedAddress': ['España']},
#        'categories': [{'id': '4bf58dd8d48988d14d941735',
#          'name': 'Paella Restaurant',
#          'pluralName': 'Paella Restaurants',
#          'shortName': 'Paella',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/paella_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-54df5a65498e7eda5ddacacb-53'}]}]}}

# %% [markdown]
# ###### We found 55 venues in Segovia Centro

# %%
nearby_venues.head(5)
# Out:
#                                      name          categories        lat  \
# 0                     Catedral de Segovia              Church  40.950129
# 1                  Restaurante José María  Spanish Restaurant  40.950509
# 2                             Plaza Mayor               Plaza  40.950176
# 5  Hotel Eurostars Convento Capuchinos 5*               Hotel  40.952068
# 6                              El Redebal  Spanish Restaurant  40.948256
#
#         lng
# 0 -4.125484
# 1 -4.122548
# 2 -4.124078
# 5 -4.123042
# 6 -4.121843

# %%
#### We are going to drop any "shop" category venue as we do not consider them trigger venues. Firstly, we replace whatevery the shop is named to "Shop".
import re
categories = nearby_venues.categories
categories.replace('.*Shop','Shop', regex=True, inplace = True)
categories
# Out:
# 0                            Church
# 1                Spanish Restaurant
# 2                             Plaza
# 5                             Hotel
# 6                Spanish Restaurant
# 7                               Bar
# 8                              Park
# 9                Spanish Restaurant
# 11               Spanish Restaurant
# 12                 Tapas Restaurant
# 13                              Bar
# 14                            Plaza
# 15                              Bar
# 16                              Bar
# 18                    Historic Site
# 19               Spanish Restaurant
# 20                       Restaurant
# 21                Indian Restaurant
# 22    Vegetarian / Vegan Restaurant
# 23                         Wine Bar
# 24                        Rock Club
# 25                          Theater
# 26               Spanish Restaurant
# 27                       Restaurant
# 28               Spanish Restaurant
# 29                   Scenic Lookout
# 30                       Restaurant
# 31               Spanish Restaurant
# 32                            Hotel
# 33               Spanish Restaurant
# 34               Spanish Restaurant
# 35                 Tapas Restaurant
# 36               Spanish Restaurant
# 37               Spanish Restaurant
# 38                 Tapas Restaurant
# 39                            Hotel
# 40                    Historic Site
# 41               Spanish Restaurant
# 42                              Bar
# 43                              Bar
# 44                      Beer Garden
# 45                 Sculpture Garden
# 46              American Restaurant
# 47                              Bar
# 48                           Museum
# 50               Spanish Restaurant
# 51                            Hotel
# 52                       Restaurant
# 53                Paella Restaurant
# Name: categories, dtype: object

# %%
#Exclude the "Shop" category venues.
nearby_venues = nearby_venues[nearby_venues.categories != "Shop"]
#Exclude the only one case "Grocery Store" venue:
nearby_venues = nearby_venues[nearby_venues.categories != "Grocery Store"]
nearby_venues
# Out:
#                                        name                     categories  \
# 0                       Catedral de Segovia                         Church
# 1                    Restaurante José María             Spanish Restaurant
# 2                               Plaza Mayor                          Plaza
# 5    Hotel Eurostars Convento Capuchinos 5*                          Hotel
# 6                                El Redebal             Spanish Restaurant
# 7                                  El Sitio                            Bar
# 8              Paseo Del Salón De Isabel II                           Park
# 9                      Cueva de San Esteban             Spanish Restaurant
# 11                      Restaurante Villena             Spanish Restaurant
# 12                         El Fogón Sefardí               Tapas Restaurant
# 13                                  Santana                            Bar
# 14  Plazas de San Martín y Medina del Campo                          Plaza
# 15                             Taberna Rubi                            Bar
# 16                El Figón De Los Comuneros                            Bar
# 18                     Barrio de la Judería                  Historic Site
# 19                                Narizotas             Spanish Restaurant
# 20                               El Hidalgo                     Restaurant
# 21                               La Judería              Indian Restaurant
# 22                              La Almuzara  Vegetarian / Vegan Restaurant
# 23                              La Tasquina                       Wine Bar
# 24                                Beat Club                      Rock Club
# 25                        Teatro Juan Bravo                        Theater
# 26                               Café Jeyma             Spanish Restaurant
# 27                   Restaurante California                     Restaurant
# 28                         Meson Don Jimeno             Spanish Restaurant
# 29                      Mirador de Canaleja                 Scenic Lookout
# 30                             Julián Duque                     Restaurant
# 31                               Casa Duque             Spanish Restaurant
# 32                        Hotel Los Linajes                          Hotel
# 33                         Meson El Cordero             Spanish Restaurant
# 34                       Restaurante Lázaro             Spanish Restaurant
# 35                 Cafe Restaurante Infante               Tapas Restaurant
# 36                             Las Tres BBB             Spanish Restaurant
# 37                            El Bernardino             Spanish Restaurant
# 38                    La Bodega del Barbero               Tapas Restaurant
# 39                         Hotel Don Felipe                          Hotel
# 40            Casa Museo De Antonio Machado                  Historic Site
# 41                            La Concepción             Spanish Restaurant
# 42                              Bar Socorro                            Bar
# 43                                   El Ojo                            Bar
# 44                                Canavan's                    Beer Garden
# 45                   Monumento a Juan Bravo               Sculpture Garden
# 46                       Foster's Hollywood            American Restaurant
# 47                      Las Cuevas de Duque                            Bar
# 48                         Museo de Segovia                         Museum
# 50                              La Floresta             Spanish Restaurant
# 51                Hotel Palacio San Facundo                          Hotel
# 52                       VIPS Smart Segovia                     Restaurant
# 53                       Taberna de Volapie              Paella Restaurant
#
#           lat       lng
# 0   40.950129 -4.125484
# 1   40.950509 -4.122548
# 2   40.950176 -4.124078
# 5   40.952068 -4.123042
# 6   40.948256 -4.121843
# 7   40.949792 -4.123003
# 8   40.948641 -4.123335
# 9   40.951251 -4.124472
# 11  40.952170 -4.122966
# 12  40.949629 -4.124280
# 13  40.949645 -4.122629
# 14  40.948744 -4.121752
# 15  40.950393 -4.124475
# 16  40.949855 -4.123007
# 18  40.948684 -4.122216
# 19  40.948736 -4.121635
# 20  40.949325 -4.122078
# 21  40.949532 -4.124928
# 22  40.950919 -4.126267
# 23  40.951020 -4.123439
# 24  40.947657 -4.122019
# 25  40.950331 -4.123959
# 26  40.950471 -4.123620
# 27  40.946734 -4.121497
# 28  40.952049 -4.128871
# 29  40.947785 -4.120437
# 30  40.950402 -4.123840
# 31  40.947839 -4.119838
# 32  40.952589 -4.125339
# 33  40.947252 -4.119706
# 34  40.950027 -4.123405
# 35  40.950035 -4.123983
# 36  40.950266 -4.124145
# 37  40.947788 -4.120233
# 38  40.948403 -4.121623
# 39  40.951695 -4.128463
# 40  40.951575 -4.125843
# 41  40.950388 -4.124351
# 42  40.950133 -4.127354
# 43  40.948808 -4.121398
# 44  40.950465 -4.122370
# 45  40.948592 -4.121617
# 46  40.948486 -4.122178
# 47  40.947765 -4.119531
# 48  40.950416 -4.128396
# 50  40.949977 -4.118299
# 51  40.950216 -4.120390
# 52  40.947787 -4.119683
# 53  40.947763 -4.119224

# %% [markdown]
# #### LA GRANJA NEIGHBOURHOOD

# %% [markdown]
# #### Now we are going to obtain the same information about the venues throguh Foursquare for La Granja neighbourhood. Our main focus are bars, restaurants and trigger venues.

# %%
#Obtain the geographical coordinades of Nueva Segovia
address = 'El Real Sitio de San Ildefonso, Spain'

geolocator = Nominatim(user_agent="toronto_explorer")
location = geolocator.geocode(address)
latitude_nueva = location.latitude
longitude_nueva = location.longitude
print('The geograpical coordinate of Nueva Segovia are {}, {}.'.format(latitude_nueva, longitude_nueva))
# Out:
# The geograpical coordinate of Nueva Segovia are 40.9006043, -4.0054657.

# %%
#GET request URL
LIMIT_nueva = 100
radius_nueva = 1000
 
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(CLIENT_ID,CLIENT_SECRET, VERSION, latitude_nueva, longitude_nueva, radius_nueva, LIMIT_nueva)
results2 = requests.get(url).json()

# %%
results2
# Out:
# {'meta': {'code': 200, 'requestId': '5f36b3f82bbd33138045604c'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': 'Open now', 'key': 'openNow'}]},
#   'headerLocation': 'San Ildefonso',
#   'headerFullLocation': 'San Ildefonso',
#   'headerLocationGranularity': 'city',
#   'totalResults': 21,
#   'suggestedBounds': {'ne': {'lat': 40.90960430900001,
#     'lng': -3.9935807416149527},
#    'sw': {'lat': 40.891604290999986, 'lng': -4.017350658385047}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b5b21bbf964a5205be528e3',
#        'name': 'Casa Zaca',
#        'location': {'address': 'Calle Embajadores, 6, BAJO',
#         'lat': 40.90016528,
#         'lng': -4.00724579,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.90016528,
#           'lng': -4.00724579}],
#         'distance': 157,
#         'postalCode': '40100',
#         'cc': 'ES',
#         'city': 'La Granja de San Ildefonso',
#         'state': 'Castilla y León',
#         'country': 'España',
#         'formattedAddress': ['Calle Embajadores, 6, BAJO',
#          '40100 La Granja de San Ildefonso Castilla y León',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d150941735',
#          'name': 'Spanish Restaurant',
#          'pluralName': 'Spanish Restaurants',
#          'shortName': 'Spanish',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/spanish_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b5b21bbf964a5205be528e3-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b7fb262f964a520953930e3',
#        'name': 'Hotel Parador de La Granja',
#        'location': {'address': 'Calle de los Infantes, 3',
#         'lat': 40.90135335293582,
#         'lng': -4.007445359253282,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.90135335293582,
#           'lng': -4.007445359253282}],
#         'distance': 186,
#         'postalCode': '40100',
#         'cc': 'ES',
#         'city': 'La Granja de San Ildefonso',
#         'state': 'Castilla y León',
#         'country': 'España',
#         'formattedAddress': ['Calle de los Infantes, 3',
#          '40100 La Granja de San Ildefonso Castilla y León',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b7fb262f964a520953930e3-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4adcda38f964a5205a3c21e3',
#        'name': 'Palacio Real de La Granja',
#        'location': {'address': 'Plaza de España 17',
#         'lat': 40.89773297103303,
#         'lng': -4.004709720611572,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.89773297103303,
#           'lng': -4.004709720611572}],
#         'distance': 325,
#         'postalCode': '40100',
#         'cc': 'ES',
#         'city': 'La Granja de San Ildefonso',
#         'state': 'Castilla y León',
#         'country': 'España',
#         'formattedAddress': ['Plaza de España 17',
#          '40100 La Granja de San Ildefonso Castilla y León',
#          'España']},
#        'categories': [{'id': '52e81612bcbc57f1066b7a14',
#          'name': 'Palace',
#          'pluralName': 'Palaces',
#          'shortName': 'Palace',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4adcda38f964a5205a3c21e3-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e3fddcad164b52911cb63f4',
#        'name': 'Jardines del Palacio Real de La Granja',
#        'location': {'lat': 40.89703292174769,
#         'lng': -4.005606967230238,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.89703292174769,
#           'lng': -4.005606967230238}],
#         'distance': 397,
#         'cc': 'ES',
#         'city': 'La Granja de San Ildefonso',
#         'state': 'Castilla y León',
#         'country': 'España',
#         'formattedAddress': ['La Granja de San Ildefonso Castilla y León',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d15a941735',
#          'name': 'Garden',
#          'pluralName': 'Gardens',
#          'shortName': 'Garden',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/garden_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e3fddcad164b52911cb63f4-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4dfc9832fa76c83b6e7d15dd',
#        'name': 'Taberna el Hábito',
#        'location': {'address': 'C. Baños',
#         'lat': 40.90115083360998,
#         'lng': -4.004094852171217,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.90115083360998,
#           'lng': -4.004094852171217}],
#         'distance': 130,
#         'cc': 'ES',
#         'city': 'La Granja de San Idelfonso',
#         'country': 'España',
#         'formattedAddress': ['C. Baños',
#          'La Granja de San Idelfonso',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'shortName': 'Restaurant',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4dfc9832fa76c83b6e7d15dd-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5071666de4b0f322435179ff',
#        'name': 'La Panadería',
#        'location': {'address': 'C. Lecheros, 11',
#         'lat': 40.901451513584526,
#         'lng': -4.00640758876719,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.901451513584526,
#           'lng': -4.00640758876719}],
#         'distance': 123,
#         'postalCode': '40100',
#         'cc': 'ES',
#         'city': 'La Granja de San Ildefonso',
#         'state': 'Castilla y León',
#         'country': 'España',
#         'formattedAddress': ['C. Lecheros, 11',
#          '40100 La Granja de San Ildefonso Castilla y León',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'shortName': 'Restaurant',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5071666de4b0f322435179ff-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c8bfb37509e370405342f55',
#        'name': 'Hotel Roma',
#        'location': {'lat': 40.900224568464836,
#         'lng': -4.008986581883003,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.900224568464836,
#           'lng': -4.008986581883003}],
#         'distance': 299,
#         'cc': 'ES',
#         'city': 'La Granja de San Ildefonso',
#         'state': 'Castilla y León',
#         'country': 'España',
#         'formattedAddress': ['La Granja de San Ildefonso Castilla y León',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c8bfb37509e370405342f55-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4da0b7e40f578cfa467d7a18',
#        'name': 'Pizzeria Dumbo',
#        'location': {'lat': 40.901981610941846,
#         'lng': -4.006719675126056,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.901981610941846,
#           'lng': -4.006719675126056}],
#         'distance': 186,
#         'cc': 'ES',
#         'city': 'La Granja de San Ildefonso',
#         'state': 'Castilla y León',
#         'country': 'España',
#         'formattedAddress': ['La Granja de San Ildefonso Castilla y León',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4da0b7e40f578cfa467d7a18-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bdc12fc63c5c9b6cf542a68',
#        'name': 'Bar El Gallo',
#        'location': {'address': 'Callejon del gallo',
#         'lat': 40.90060726062097,
#         'lng': -4.006117354451089,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.90060726062097,
#           'lng': -4.006117354451089}],
#         'distance': 54,
#         'cc': 'ES',
#         'city': 'La Granja de San Ildefonso',
#         'state': 'Castilla y León',
#         'country': 'España',
#         'formattedAddress': ['Callejon del gallo',
#          'La Granja de San Ildefonso Castilla y León',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bdc12fc63c5c9b6cf542a68-8'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c4226fee26920a1a0a05fe7',
#        'name': 'La Fundición',
#        'location': {'address': 'Calandria 1',
#         'lat': 40.90076130587474,
#         'lng': -4.004974452767539,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.90076130587474,
#           'lng': -4.004974452767539}],
#         'distance': 44,
#         'cc': 'ES',
#         'city': 'La Granja de San Ildefonso',
#         'state': 'Castilla y León',
#         'country': 'España',
#         'formattedAddress': ['Calandria 1',
#          'La Granja de San Ildefonso Castilla y León',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d116941735',
#          'name': 'Bar',
#          'pluralName': 'Bars',
#          'shortName': 'Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c4226fee26920a1a0a05fe7-9'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4dea4335b0fb8293f7cf11e5',
#        'name': 'La Chocolateria',
#        'location': {'address': 'Plaza de España 1',
#         'lat': 40.89927729357102,
#         'lng': -4.006758404108668,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.89927729357102,
#           'lng': -4.006758404108668}],
#         'distance': 183,
#         'cc': 'ES',
#         'city': 'La Granja de San Ildefonso',
#         'state': 'Castilla y León',
#         'country': 'España',
#         'formattedAddress': ['Plaza de España 1',
#          'La Granja de San Ildefonso Castilla y León',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4dea4335b0fb8293f7cf11e5-10'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d0381b637036dcbb7650afb',
#        'name': 'Taberna del pelón',
#        'location': {'address': 'c/Carral 4',
#         'lat': 40.8999923464443,
#         'lng': -4.006648790351176,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.8999923464443,
#           'lng': -4.006648790351176}],
#         'distance': 120,
#         'postalCode': '40100',
#         'cc': 'ES',
#         'city': 'La Granja de San Ildefonso',
#         'state': 'Castilla y León',
#         'country': 'España',
#         'formattedAddress': ['c/Carral 4',
#          '40100 La Granja de San Ildefonso Castilla y León',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'shortName': 'Restaurant',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d0381b637036dcbb7650afb-11'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cf1293c1c158cfa11f1ceb5',
#        'name': 'La Golondrina',
#        'location': {'lat': 40.90196277849513,
#         'lng': -4.006690114756114,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.90196277849513,
#           'lng': -4.006690114756114}],
#         'distance': 182,
#         'cc': 'ES',
#         'country': 'España',
#         'formattedAddress': ['España']},
#        'categories': [{'id': '4bf58dd8d48988d150941735',
#          'name': 'Spanish Restaurant',
#          'pluralName': 'Spanish Restaurants',
#          'shortName': 'Spanish',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/spanish_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cf1293c1c158cfa11f1ceb5-12'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ede2d90f790c0454a1cf57d',
#        'name': 'Restaurante Madrid',
#        'location': {'address': 'Plaza de la Fruta, 3, BAJO',
#         'lat': 40.9005976,
#         'lng': -4.007825,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.9005976,
#           'lng': -4.007825}],
#         'distance': 198,
#         'postalCode': '40100',
#         'cc': 'ES',
#         'city': 'La Granja de San Ildefonso',
#         'state': 'Castilla y León',
#         'country': 'España',
#         'formattedAddress': ['Plaza de la Fruta, 3, BAJO',
#          '40100 La Granja de San Ildefonso Castilla y León',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'shortName': 'Restaurant',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ede2d90f790c0454a1cf57d-13'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4dc7d0a4d4c0ad9c0fbfcb0c',
#        'name': 'La Fragua',
#        'location': {'lat': 40.899917,
#         'lng': -4.007241725921631,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.899917,
#           'lng': -4.007241725921631}],
#         'distance': 167,
#         'cc': 'ES',
#         'city': 'Segovia',
#         'state': 'Castilla y León',
#         'country': 'España',
#         'formattedAddress': ['Segovia Castilla y León', 'España']},
#        'categories': [{'id': '4bf58dd8d48988d150941735',
#          'name': 'Spanish Restaurant',
#          'pluralName': 'Spanish Restaurants',
#          'shortName': 'Spanish',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/spanish_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4dc7d0a4d4c0ad9c0fbfcb0c-14'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4daa99286a2303012f11fac9',
#        'name': 'Restaurante Bar Segovia',
#        'location': {'address': 'C/Infantes 1',
#         'lat': 40.900367,
#         'lng': -4.008658,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.900367,
#           'lng': -4.008658}],
#         'distance': 269,
#         'cc': 'ES',
#         'city': 'La Granja de San Ildefonso',
#         'state': 'Castilla y León',
#         'country': 'España',
#         'formattedAddress': ['C/Infantes 1',
#          'La Granja de San Ildefonso Castilla y León',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d150941735',
#          'name': 'Spanish Restaurant',
#          'pluralName': 'Spanish Restaurants',
#          'shortName': 'Spanish',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/spanish_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4daa99286a2303012f11fac9-15'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c557dff728920a1d8e58084',
#        'name': 'La Chata',
#        'location': {'address': 'Plaza de España, 5',
#         'lat': 40.89935925250359,
#         'lng': -4.0069395505014285,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.89935925250359,
#           'lng': -4.0069395505014285}],
#         'distance': 185,
#         'postalCode': '40100',
#         'cc': 'ES',
#         'city': 'La Granja de San Ildefonso',
#         'state': 'Castilla y León',
#         'country': 'España',
#         'formattedAddress': ['Plaza de España, 5',
#          '40100 La Granja de San Ildefonso Castilla y León',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d150941735',
#          'name': 'Spanish Restaurant',
#          'pluralName': 'Spanish Restaurants',
#          'shortName': 'Spanish',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/spanish_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c557dff728920a1d8e58084-16'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5ad750e98e886a2227738881',
#        'name': 'Fuente De Los Dragones Altos',
#        'location': {'address': 'Palacio Real De La Granja De San Ildefonso',
#         'lat': 40.895776,
#         'lng': -4.00501,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.895776,
#           'lng': -4.00501}],
#         'distance': 538,
#         'postalCode': '40100',
#         'cc': 'ES',
#         'city': 'La Granja de San Ildefonso',
#         'state': 'Castilla y León',
#         'country': 'España',
#         'formattedAddress': ['Palacio Real De La Granja De San Ildefonso',
#          '40100 La Granja de San Ildefonso Castilla y León',
#          'España']},
#        'categories': [{'id': '56aa371be4b08b9a8d573547',
#          'name': 'Fountain',
#          'pluralName': 'Fountains',
#          'shortName': 'Fountain',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/plaza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5ad750e98e886a2227738881-17'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4fe5ec18e4b0a0c3b023f798',
#        'name': 'Fuente de la Fama',
#        'location': {'lat': 40.89580283287218,
#         'lng': -4.006683826446533,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.89580283287218,
#           'lng': -4.006683826446533}],
#         'distance': 544,
#         'cc': 'ES',
#         'city': 'La Granja de San Ildefonso',
#         'state': 'Castilla y León',
#         'country': 'España',
#         'formattedAddress': ['La Granja de San Ildefonso Castilla y León',
#          'España']},
#        'categories': [{'id': '56aa371be4b08b9a8d573547',
#          'name': 'Fountain',
#          'pluralName': 'Fountains',
#          'shortName': 'Fountain',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/plaza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4fe5ec18e4b0a0c3b023f798-18'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e1ce25215207c4cbec50c79',
#        'name': 'Restaurante Canónigos',
#        'location': {'address': 'Plaza de Canónigos, 2',
#         'lat': 40.89925352341129,
#         'lng': -4.0052729845047,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.89925352341129,
#           'lng': -4.0052729845047}],
#         'distance': 151,
#         'postalCode': '40100',
#         'cc': 'ES',
#         'city': 'La Granja de San Ildefonso',
#         'state': 'Castilla y León',
#         'country': 'España',
#         'formattedAddress': ['Plaza de Canónigos, 2',
#          '40100 La Granja de San Ildefonso Castilla y León',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d14d941735',
#          'name': 'Paella Restaurant',
#          'pluralName': 'Paella Restaurants',
#          'shortName': 'Paella',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/paella_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e1ce25215207c4cbec50c79-19'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4fe5e87fe4b0c9ca89c59a9f',
#        'name': 'Fuente De los Baños De Diana',
#        'location': {'lat': 40.893863677978516,
#         'lng': -4.008371353149414,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.893863677978516,
#           'lng': -4.008371353149414}],
#         'distance': 789,
#         'cc': 'ES',
#         'country': 'España',
#         'formattedAddress': ['España']},
#        'categories': [{'id': '56aa371be4b08b9a8d573547',
#          'name': 'Fountain',
#          'pluralName': 'Fountains',
#          'shortName': 'Fountain',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/plaza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4fe5e87fe4b0c9ca89c59a9f-20'}]}]}}

# %% [markdown]
# ##### We found 24 venues in La Granja

# %%
nearby_venues2.categories
# Out:
# 0     Spanish Restaurant
# 1                  Hotel
# 2                 Palace
# 3                 Garden
# 4             Restaurant
# 5             Restaurant
# 6                  Hotel
# 7     Italian Restaurant
# 8                   Café
# 9                    Bar
# 10                  Café
# 11            Restaurant
# 12    Spanish Restaurant
# 13            Restaurant
# 14    Spanish Restaurant
# 15            Restaurant
# 16    Spanish Restaurant
# 17      Sculpture Garden
# 18    Spanish Restaurant
# 19    Spanish Restaurant
# 20              Fountain
# 21              Fountain
# 22     Paella Restaurant
# 23              Fountain
# Name: categories, dtype: object

# %% [markdown]
# ###  DATA ANALYSIS

# %% [markdown]
# #### In this step we are going to perform an Exploratory Data Analysis

# %%
categories_count_LG= nearby_venues2['categories'].value_counts()
categories_count_LG
# Out:
# Spanish Restaurant    6
# Restaurant            5
# Fountain              3
# Hotel                 2
# Café                  2
# Paella Restaurant     1
# Palace                1
# Italian Restaurant    1
# Bar                   1
# Garden                1
# Sculpture Garden      1
# Name: categories, dtype: int64

# %%
categories_count_C = nearby_venues['categories'].value_counts()
categories_count_C
# Out:
# Spanish Restaurant               14
# Bar                               7
# Restaurant                        4
# Hotel                             4
# Tapas Restaurant                  3
# Plaza                             2
# Historic Site                     2
# Indian Restaurant                 1
# Beer Garden                       1
# Sculpture Garden                  1
# Vegetarian / Vegan Restaurant     1
# American Restaurant               1
# Park                              1
# Museum                            1
# Rock Club                         1
# Wine Bar                          1
# Theater                           1
# Scenic Lookout                    1
# Paella Restaurant                 1
# Church                            1
# Name: categories, dtype: int64

# %% [markdown]
# #### Additionally, we are going to produce a map to get a visual feeling of the neighbourhood and the venues in each neighbourhood

# %%
map_centro = folium.Map(location=[latitude_centro, longitude_centro], zoom_start=27)
map_centro
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map_lagranja = folium.Map(location=[latitude_nueva, longitude_nueva], zoom_start=18)
map_lagranja
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## 4. Results and Discussion

# %% [markdown]
# As we can see in **LA GRANJA** neighbourhood there are overall less venues. Within this venues:
# 1) There is only one restaurant providing foreing countrie's meals: Italian Restaurant. There are no Chinese restaurants. However, due to the qualitative analysis conducted previously we now there are a few Chineses restaurants. Therefore, we inferred these restaruants are not relevant enough and that is the reason Foursquare does not include them.
#
# We do not focus on the relevance of Chineses restaurants as we have qualitative data that supports that Segovians like Chinese food. We are going to focus on the competitors:
# 2) The main competitors are Spanish restaurants, which would go in line with the Segovian's behaviour essence of the restaurants they often visit. However, we can notice that the fact that there are few trigger venues (palace, garden, sculpture garden, fountain) can help us conclude this is not aligned with Segovian's behaviour essence.
#
# 3) In the map we can observe the venues are spread around the neighbourhood in a fairly similar proportion. This shows it is a daily used area with no specific agglomerations.
#
# On the other hand, exploring **CENTRO** neighbourhood, we can observe the following:
# 1) Greater variety of foreing food restaurant (American, Indian, Vegetarian) which helps us conclude customers having meals in this neighbourhood are prompt to eat spanish food but also non-spanish food.
#
# 2) Competitors are mainly Spanish restaurants, which matches the Segovians behaviour essence.
#
# 3) More trigger venues.
#
# 4) In the map we can observe the venues are concentrated are we there are lots of them very close to each other. This hows it is an area with specific agglomerations which match the Segovians behaviour.
#
# **CONTRADICTION: **
#
# However, based on qualitative data we now there are no Chinese restaurants in CENTRO but there are some in LA GRANJA. Then, what is the answer to our initial question?
#
# The main characteristic of this new Chinese restaurant is not its but (which is implicit in the business) but the objective of fussioning Segovians behaviour essence with the restaurant. Although the Chinese restaurants in LA GRANJA (qualitative data) are succeding, they are not succeding in Segovians behaviour essence. For example, Segovians go to LA GRANJA Chinese restaurants for informal ocassions, in specific timings and they do not consider them as one of their usual restaurants although they love their food. This new restaurant wants to attrack customers in their frequent social meetings and make them feel the restaurant as one of their usual ones.

# %% [markdown]
# ## 5. Conclusion

# %% [markdown]
# This study allows to focus and analyse with more precision the potential place of the new Chinese restaurant in Segovia.
# A previous qualitative study was conducted by interviewing Segovians to get to know their habits within the city, their social life and the predisposition to go to a Chinese restaurant. The results showed how they were very predisposed to go to a Chinese restaurant, but this event was not part of their usual habit of socializing in Segovia Centro neighbourhood.
#
# Therefore, we conducted this quantitative data analysis to have a clear vision of the market in Segovia, considering the urban area, La Granja and the medieval city center, Centro. In a very effective way, we obtained the data making a call to the Foursquare API using their respectives latitude and logitud to get the most relevant venues within each area. Next, it was very important to prepare our data, eliminating venues which were not of interested and could cause outliers. Finally, we analysed the data based on the frequency of each venue in each restaurant so we could make conclusions about competitors, top venues, tendencies, etc., all together with the context of the qualitative results. Additionally, we produced a map of each neightbourhood as to see the distribution of the venues and conclude which characteristics match with Segovians behaviour essence.
#
# Finally, we conclude the most suitable place is within Centro neighbourhood, because although it is going to be a challenge as people is not used to Chinese restaurants in that area, this location takes the advantage of incorporating the key aspect of Segovian behaviour essence.
